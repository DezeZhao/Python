# %%
import requests
from lxml import etree
import json

def getOnePage(n):
    #链接
    url=f'https://maoyan.com/board/4?offset={n*10}'
    #告诉服务器，我们是浏览器，字典
    header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}
    #调用
    r=requests.get(url,headers=header)
    return r.text

def parse(text):
    #print(text)
    html=etree.HTML(text)
    #print(html)
    #names是列表
    names=html.xpath('//div[@class="movie-item-info"]/p[@class="name"]/a/@title')
    releasetimes=html.xpath('//p[@class="releasetime"]/text()')
    #zip函数时拉链函数
    item = {}  # dict
    for name,releasetime in zip(names,releasetimes):
        item['name']=name;
        item['releasetime']=releasetime;
        yield item#生成器

#保存数据
def save2File(data):
    with open('movie.json','a',encoding='utf-8') as f:
        #把字典 列表 等转换为字符串  之后才能写入文件
        data=json.dumps(data,ensure_ascii=False)+'\n'
        f.write(data)

if __name__=='__main__':
    for n in range(0,10):
        text=getOnePage(n)
        items=parse(text)
        for item in items:
            print(item)
            save2File(item)
# Out:
# {'name': '霸王别姬', 'releasetime': '上映时间：1993-07-26'}
# {'name': '肖申克的救赎', 'releasetime': '上映时间：1994-09-10(加拿大)'}
# {'name': '这个杀手不太冷', 'releasetime': '上映时间：1994-09-14(法国)'}
# {'name': '罗马假日', 'releasetime': '上映时间：1953-08-20(意大利)'}
# {'name': '泰坦尼克号', 'releasetime': '上映时间：1998-04-03'}
# {'name': '唐伯虎点秋香', 'releasetime': '上映时间：1993-07-01(中国香港)'}
# {'name': '乱世佳人', 'releasetime': '上映时间：1939-12-15(美国)'}
# {'name': '魂断蓝桥', 'releasetime': '上映时间：1940-05-17(美国)'}
# {'name': '辛德勒的名单', 'releasetime': '上映时间：1993-11-30(美国)'}
# {'name': '天空之城', 'releasetime': '上映时间：1992-05-01'}
# {'name': '大闹天宫', 'releasetime': '上映时间：1965-12-31'}
# {'name': '音乐之声', 'releasetime': '上映时间：1965-03-02(美国)'}
# {'name': '喜剧之王', 'releasetime': '上映时间：1999-02-13(中国香港)'}
# {'name': '春光乍泄', 'releasetime': '上映时间：1997-05-17(法国)'}
# {'name': '剪刀手爱德华', 'releasetime': '上映时间：1990-12-06(美国)'}
# {'name': '黑客帝国', 'releasetime': '上映时间：2000-01-14'}
# {'name': '指环王3：王者无敌', 'releasetime': '上映时间：2004-03-15'}
# {'name': '哈利·波特与魔法石', 'releasetime': '上映时间：2002-01-26'}
# {'name': '加勒比海盗', 'releasetime': '上映时间：2003-11-21'}
# {'name': '楚门的世界', 'releasetime': '上映时间：1998-06-05(美国)'}
# {'name': '无间道', 'releasetime': '上映时间：2003-09-05'}
# {'name': '蝙蝠侠：黑暗骑士', 'releasetime': '上映时间：2008-07-14(阿根廷)'}
# {'name': '教父2', 'releasetime': '上映时间：1974-12-12(美国)'}
# {'name': '射雕英雄传之东成西就', 'releasetime': '上映时间：1993-02-05(中国香港)'}
# {'name': '指环王1：护戒使者', 'releasetime': '上映时间：2002-04-04'}
# {'name': '机器人总动员', 'releasetime': '上映时间：2008-06-27(美国)'}
# {'name': '指环王2：双塔奇兵', 'releasetime': '上映时间：2003-04-25'}
# {'name': '天堂电影院', 'releasetime': '上映时间：1988-11-17(意大利)'}
# {'name': '狮子王', 'releasetime': '上映时间：1995-07-15'}
# {'name': '活着', 'releasetime': '上映时间：1994-05-17(法国)'}
# {'name': '拯救大兵瑞恩', 'releasetime': '上映时间：1998-11-13'}
# {'name': '盗梦空间', 'releasetime': '上映时间：2010-09-01'}
# {'name': '忠犬八公的故事', 'releasetime': '上映时间：2009-06-13(美国)'}
# {'name': '哈尔的移动城堡', 'releasetime': '上映时间：2004-09-05(意大利)'}
# {'name': '阿凡达', 'releasetime': '上映时间：2010-01-04'}
# {'name': '疯狂原始人', 'releasetime': '上映时间：2013-04-20'}
# {'name': '搏击俱乐部', 'releasetime': '上映时间：1999-09-10(威尼斯国际电影节)'}
# {'name': '幽灵公主', 'releasetime': '上映时间：1998-05-01'}
# {'name': 'V字仇杀队', 'releasetime': '上映时间：2005-12-11(美国)'}
# {'name': '十二怒汉', 'releasetime': '上映时间：1957-04-13(美国)'}
# {'name': '当幸福来敲门', 'releasetime': '上映时间：2008-01-17'}
# {'name': '放牛班的春天', 'releasetime': '上映时间：2004-10-16'}
# {'name': '大话西游之月光宝盒', 'releasetime': '上映时间：2014-10-24'}
# {'name': '风之谷', 'releasetime': '上映时间：1992-05'}
# {'name': '三傻大闹宝莱坞', 'releasetime': '上映时间：2011-12-08'}
# {'name': '闻香识女人', 'releasetime': '上映时间：1992-12-23(美国)'}
# {'name': '速度与激情5', 'releasetime': '上映时间：2011-05-12'}
# {'name': '勇敢的心', 'releasetime': '上映时间：1995-05-18(美国)'}
# {'name': '少年派的奇幻漂流', 'releasetime': '上映时间：2012-11-22'}
# {'name': '末代皇帝', 'releasetime': '上映时间：1987-10-23'}
# {'name': '黑客帝国3：矩阵革命', 'releasetime': '上映时间：2003-11-05'}
# {'name': '飞屋环游记', 'releasetime': '上映时间：2009-08-04'}
# {'name': '驯龙高手', 'releasetime': '上映时间：2010-05-14'}
# {'name': '怦然心动', 'releasetime': '上映时间：2010-07-26(美国)'}
# {'name': '断背山', 'releasetime': '上映时间：2005-09-02(意大利)'}
# {'name': '神偷奶爸', 'releasetime': '上映时间：2010-06-20(俄罗斯)'}
# {'name': '致命魔术', 'releasetime': '上映时间：2006-10-17(意大利)'}
# {'name': '无敌破坏王', 'releasetime': '上映时间：2012-11-06'}
# {'name': '鬼子来了', 'releasetime': '上映时间：2000-05-13(法国)'}
# {'name': '美丽心灵', 'releasetime': '上映时间：2001-12-13(美国)'}
# {'name': '蝙蝠侠：黑暗骑士崛起', 'releasetime': '上映时间：2012-08-27'}
# {'name': '哈利·波特与死亡圣器（下）', 'releasetime': '上映时间：2011-08-04'}
